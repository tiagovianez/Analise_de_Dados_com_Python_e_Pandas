# %%
print("Hello World")
# Out:
# Hello World

# %%
print("I'm learning python")
# Out:
# I'm learning python

# %%
'Estou aprendendo Python'
# Out:
# 'Estou aprendendo Python'

# %%
10 - 7
# Out:
# 3

# %%
a = 4
b = 6
soma = a + b
print(soma)
# Out:
# 10

# %%
#Criando uma variável do tipo string
frase = "Python for Data Analysis"
frase[0]
# Out:
# 'P'

# %%
#Imprima na tela o nome Python
frase[0:6]
# Out:
# 'Python'

# %%
#Imprimindo na tela quantas vezes a palavra Data aparece na frase
frase.count("Data")
# Out:
# 1

# %%
#Colocando a frase em letras maiúsculas
frase.upper()
# Out:
# 'PYTHON FOR DATA ANALYSIS'

# %%
#Colocando a frase em letras minúsculas
frase.lower()
# Out:
# 'python for data analysis'

# %%
#Alterando palavras de uma frase. Subistituindo a palavra "Python" pela palavra "Phrase"
frase.replace("Python", "Phrase")
# Out:
# 'Phrase for Data Analysis'
